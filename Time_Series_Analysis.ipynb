# %% [markdown]
# ## First step - exploratory data analisys
# #### Import required libraries

# %%
import pandas as pd
import numpy as np
import datetime as dt
import os
import warnings
from collections import UserDict
from glob import glob
import matplotlib.pyplot as plt
from IPython.display import Image
# %matplotlib inline
import matplotlib.dates as mpl_dates
import seaborn as sns
from statsmodels.tsa.ar_model import AutoReg, ar_select_order
from statsmodels.tsa.api import acf, pacf, graphics
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.preprocessing import MinMaxScaler
import math
from keras.models import Model, Sequential
from keras.layers import GRU, Dense
from keras.callbacks import EarlyStopping

# %%
holiday = pd.read_csv ('/content/holidays_events.csv')
holiday.head (10)
# Out:
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4  2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
# 5  2012-05-12  Holiday     Local        Puyo         Cantonizacion del Puyo
# 6  2012-06-23  Holiday     Local    Guaranda      Cantonizacion de Guaranda
# 7  2012-06-25  Holiday  Regional    Imbabura  Provincializacion de Imbabura
# 8  2012-06-25  Holiday     Local   Latacunga     Cantonizacion de Latacunga
# 9  2012-06-25  Holiday     Local     Machala           Fundacion de Machala
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False

# %%
oil = pd.read_csv("/content/oil.csv")

# %%
stores = pd.read_csv ('/content/stores.csv')
stores.head (10)
# Out:
#    store_nbr           city                           state type  cluster
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# 5          6          Quito                       Pichincha    D       13
# 6          7          Quito                       Pichincha    D        8
# 7          8          Quito                       Pichincha    D        8
# 8          9          Quito                       Pichincha    B        6
# 9         10          Quito                       Pichincha    C       15

# %%
transactions = pd.read_csv ('/content/transactions.csv')
transactions.head (10)
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922
# 5  2013-01-02          5          1903
# 6  2013-01-02          6          2143
# 7  2013-01-02          7          1874
# 8  2013-01-02          8          3250
# 9  2013-01-02          9          2940

# %% [markdown]
# #### Ckecking for missing values in the rows

# %%
holiday.isna().sum()
# Out:
# date           0
# type           0
# locale         0
# locale_name    0
# description    0
# transferred    0
# dtype: int64

# %%
oil.isna().sum()
# Out:
# date           0
# dcoilwtico    43
# dtype: int64

# %%
# drop the missing values
oil = oil.dropna()
oil.count ()
# Out:
# date          1175
# dcoilwtico    1175
# dtype: int64

# %%
stores.isna().sum()
# Out:
# store_nbr    0
# city         0
# state        0
# type         0
# cluster      0
# dtype: int64

# %%
transactions.isna().sum()
# Out:
# date            0
# store_nbr       0
# transactions    0
# dtype: int64

# %% [markdown]
# ####We transform the data into a date series format, since only in this way it will be possible to process the data

# %%
# convert datasets to time series
holiday['date'] = pd.to_datetime(holiday['date'])
oil['date'] = pd.to_datetime(oil['date'])
transactions['date'] = pd.to_datetime(transactions ['date'])
# Out:
# <ipython-input-11-0871ba9098ec>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oil['date'] = pd.to_datetime(oil['date'])

# %%
holiday.describe(include=[object])
# Out:
#            type    locale locale_name description
# count       350       350         350         350
# unique        6         3          24         103
# top     Holiday  National     Ecuador    Carnaval
# freq        221       174         174          10

# %%
stores.describe(include=[object])
# Out:
#          city      state type
# count      54         54   54
# unique     22         16    5
# top     Quito  Pichincha    D
# freq       18         19   18

# %% [markdown]
# ####Create a lag plot for datasets. Lag plots are used to check if a time series is random: random data should not exhibit any structure in the lag plot

# %%
pd.options.display.float_format = "{:, .2f}".format
np.set_printoptions (precision = 2)
warnings.filterwarnings ("ignore")

# import lag_plot function
from pandas.plotting import lag_plot
sns.set ()

# pass the lag argument and plot the values
# when lag = 1 the plot is essentially data [:-1] vs. data [1:]
# plot our holiday data set
lag_plot (holiday ['date'])
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %%
# plot our oil data set
lag_plot (oil ['date'])
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %%
# plot our transactions data set
lag_plot (transactions ['date'])
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %% [markdown]
# ####As we can see, the data has a clear linear structure.
#
# Create an autocorrelation plot for datasets. Autocorrelation plots applied to check randomness in time series by computing autocorrelations for data values at fluctuating time lags. It is heavily used in time series analysis and forecasting. We can calculate the correlation for current time-series observations with observations of previous time steps called lags.

# %%
# import autocorrelation plot function
from pandas.plotting import autocorrelation_plot
sns.set ()

# pass the autocorrelation argument and plot the values holiday
holiday.reset_index(inplace=True)
holiday ['date'] = holiday ['date'].apply(mpl_dates.date2num)
holiday ['date'] = holiday ['date'].astype(float)
autocorrelation_plot (holiday ['date'])
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
# pass the autocorrelation argument and plot the values oil
oil.reset_index(inplace=True)
oil ['date'] = oil ['date'].apply(mpl_dates.date2num)
oil ['date'] = oil ['date'].astype(float)
autocorrelation_plot (oil ['date'])
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
# pass the autocorrelation argument and plot the values transactions
transactions.reset_index(inplace=True)
transactions ['date'] = transactions ['date'].apply(mpl_dates.date2num)
transactions ['date'] = transactions ['date'].astype(float)
autocorrelation_plot (transactions ['date'])
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
# import plot_acf () function
from statsmodels.graphics.tsaplots import plot_acf

# plot the acf function on the holiday data set
plot_acf (holiday ['date'])
plt.show ()

# %%
# plot the acf function for oil data set
plot_acf (oil ['date'])
plt.show ()

# %%
# plot the acf function for transactions data set
plot_acf (transactions ['date'])
plt.show ()

# %%
# import plor_pacf () function
from statsmodels.graphics.tsaplots import plot_pacf

# plot the pacf fucntion on the holiday dataset
plot_pacf (holiday ['date'], lags = 20)
plt.show ()

# %%
# plot the pacf fucntion on the holiday dataset
plot_pacf (oil ['date'], lags = 30)
plt.show ()

# %%
# plot the pacf fucntion on the holiday dataset
plot_pacf (transactions['date'], lags = 40)
plt.show ()

# %% [markdown]
# ### Autoregression modeling. Autoregression is a time series model that uses observations from previous time steps as input to a regression equation to predict the value at the next time step. It is a very simple idea that can result in accurate forecasts on a range of time series problems.

# %%
# apply AutoReg model for holiday dataset
modelH = AutoReg (holiday['date'], 1)
resultsH = modelH.fit ()
resultsH.summary ()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                   date   No. Observations:                  350
# Model:                     AutoReg(1)   Log Likelihood               -1273.780
# Method:               Conditional MLE   S.D. of innovations              9.308
# Date:                Fri, 14 Jul 2023   AIC                           2553.559
# Time:                        16:50:11   BIC                           2565.124
# Sample:                             1   HQIC                          2558.163
#                                   350
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         33.7424     14.174      2.381      0.017       5.962      61.523
# date.L1        0.9983      0.001   1166.126      0.000       0.997       1.000
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0017           +0.0000j            1.0017            0.0000
# -----------------------------------------------------------------------------
# """

# %%
# apply AutoReg model for oil dataset
modelO = AutoReg (oil ['date'], 1)
resultsO = modelO.fit ()
resultsO.summary ()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                   date   No. Observations:                 1175
# Model:                     AutoReg(1)   Log Likelihood               -1516.654
# Method:               Conditional MLE   S.D. of innovations              0.881
# Date:                Fri, 14 Jul 2023   AIC                           3039.308
# Time:                        16:50:11   BIC                           3054.512
# Sample:                             1   HQIC                          3045.041
#                                  1175
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.4525      0.866      1.677      0.094      -0.245       3.150
# date.L1        1.0000   5.23e-05   1.91e+04      0.000       1.000       1.000
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------
# """

# %%
# apply AutoReg model for transcation dataset
modelT = AutoReg (transactions ['date'], 1)
resultsT = modelT.fit ()
resultsT.summary ()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                   date   No. Observations:                83488
# Model:                     AutoReg(1)   Log Likelihood               44962.067
# Method:               Conditional MLE   S.D. of innovations              0.141
# Date:                Fri, 14 Jul 2023   AIC                         -89918.135
# Time:                        16:50:11   BIC                         -89890.137
# Sample:                             1   HQIC                        -89909.569
#                                 83488
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0579      0.017      3.477      0.001       0.025       0.090
# date.L1        1.0000      1e-06   9.97e+05      0.000       1.000       1.000
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------
# """

# %% [markdown]
# ###Visualize the forecasts

# %%
# define figure style, plot package and default figure size
sns.set_style ('darkgrid')
pd.plotting.register_matplotlib_converters ()

# default figure size
sns.mpl.rc ('figure', figsize = (8, 5))

# use plot_predict and visualize forecasts for holiday dataset
figure = resultsH.plot_predict (120, 490)

# %%
# use plot_predict and visualize forecasts for oil dataset
figure = resultsO.plot_predict (120, 490)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# use plot_predict and visualize forecasts for transcation dataset
figure = resultsT.plot_predict (120, 490)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ####Plot_diagnostics indicates that the model captures the key features in the data. They help us determine visually how our model is fitting the data and if any of the basic assumptions of an OLS (ordinary least squares) model are being violated.

# %%
# define default figure size
fig = plt.figure (figsize = (18, 8))

# use plot_predict and visualize forecasts for holiday dataset
fig = resultsH.plot_diagnostics (fig = fig, lags = 30)

# %%
# define default figure size
fig = plt.figure (figsize = (18, 10))

# use plot_predict and visualize forecasts for oil dataset
fig = resultsO.plot_diagnostics (fig = fig, lags = 30)

# %%
# define default figure size
fig = plt.figure (figsize = (18, 10))

# use plot_predict and visualize forecasts for transaction dataset
fig = resultsT.plot_diagnostics (fig = fig, lags = 30)

# %% [markdown]
# # Training the model for oil dataset

# %%
from sklearn.model_selection import train_test_split
# create train set containing only the model features
X = oil

X_train, X_test = train_test_split(X, test_size=0.33, random_state=42)

print ('Training data shape X: ', X_train.shape)
print ('Test data shape X: ', X_test.shape)
# Out:
# Training data shape X:  (787, 3)
# Test data shape X:  (388, 3)

# %%
# scale train data to be in range (0, 1)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler ()
X_train = scaler.fit_transform (X_train)

# scale test data to be in range (0, 1)
X_test = scaler.transform (X_test)

# specify the number of steps to forecast ahead
HORIZON = 3
print ('Forecasting horizon: ', HORIZON, 'days')
# Out:
# Forecasting horizon:  3 days

# %%
# make predictions on the test data
training_window = 720

history = [x for x in X_train]
history = history [(-training_window):]
predictions = list ()

for t in range (X_test.shape [0]):
    modelO = AutoReg (oil ['date'], 1)
    modelO_fit = modelH.fit ()
    yhat = modelO_fit.predict
    predictions.append (yhat)
    obs = list (X_test [t])
    # move the trainig window
    history.append (obs [0])
    history.pop (0)
    print (X_test [t])
    print (t+1, ': predicted =', yhat, 'expected =', obs)
# Out:
# [0.56 0.56 0.18]
# 1 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7cfa9b0>> expected = [0.562962962962963, 0.5631981187536734, 0.18103033220991815]
# [0.36 0.36 0.78]
# 2 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a37040>> expected = [0.36378600823045265, 0.3633156966490301, 0.7780452575830524]
# [0.16 0.16 0.91]
# 3 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7cf96f0>> expected = [0.16296296296296295, 0.16343327454438494, 0.90912373615792]
# [0.18 0.18 0.83]
# 4 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a8370e20>> expected = [0.17695473251028807, 0.17695473251028737, 0.8337746750120366]
# [0.63 0.63 0.12]
# 5 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bebd90>> expected = [0.6279835390946502, 0.6284538506760722, 0.12156957149735198]
# [0.4  0.4  0.59]
# 6 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a356f0>> expected = [0.4049382716049383, 0.40446796002351526, 0.5895522388059701]
# [0.97 0.97 0.22]
# 7 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a35810>> expected = [0.9711934156378601, 0.9711934156378597, 0.21593644679826673]
# [0.71 0.71 0.17]
# 8 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beada0>> expected = [0.7102880658436215, 0.7107583774250443, 0.17007703418391917]
# [0.05 0.05 0.83]
# 9 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beb790>> expected = [0.04938271604938271, 0.049382716049382935, 0.8304044294655754]
# [0.2 0.2 0.8]
# 10 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8670>> expected = [0.19588477366255144, 0.19635508524397416, 0.7952575830524794]
# [0.28 0.28 0.89]
# 11 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8760>> expected = [0.2831275720164609, 0.2833627278071713, 0.8909484833895039]
# [0.31 0.31 0.91]
# 12 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beaa10>> expected = [0.30534979423868314, 0.3051146384479715, 0.9103273952816561]
# [0.78 0.78 0.23]
# 13 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bebd60>> expected = [0.7777777777777778, 0.7777777777777768, 0.2319451131439576]
# [0.42 0.42 0.39]
# 14 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bea560>> expected = [0.41646090534979424, 0.4162257495590822, 0.3908281174771304]
# [0.02 0.02 0.83]
# 15 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beb2e0>> expected = [0.019753086419753086, 0.01998824221046469, 0.8322099181511796]
# [0.28 0.28 0.87]
# 16 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bea320>> expected = [0.2839506172839506, 0.2839506172839492, 0.8730139624458352]
# [0.47 0.47 0.25]
# 17 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bea350>> expected = [0.46831275720164606, 0.46854791299235643, 0.25132402503610973]
# [0.29 0.29 0.89]
# 18 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8e20>> expected = [0.29300411522633746, 0.29276895943562486, 0.8931150698122291]
# [0.13 0.13 0.96]
# 19 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be9d80>> expected = [0.1316872427983539, 0.1316872427983533, 0.9551035146846413]
# [0.49 0.49 0.35]
# 20 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beaf20>> expected = [0.4905349794238683, 0.4902998236331566, 0.35086663456908995]
# [0.26 0.26 0.87]
# 21 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8c40>> expected = [0.2625514403292181, 0.2627865961199287, 0.8680789600385169]
# [0.73 0.73 0.26]
# 22 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be83a0>> expected = [0.7283950617283951, 0.7283950617283939, 0.2595089070775156]
# [0.33 0.33 0.91]
# 23 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8f40>> expected = [0.3251028806584362, 0.3251028806584362, 0.9074386133846893]
# [0.47 0.47 0.21]
# 24 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be9d20>> expected = [0.4707818930041152, 0.4703115814226919, 0.2087144920558498]
# [0.63 0.63 0.15]
# 25 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beac20>> expected = [0.6271604938271605, 0.6266901822457367, 0.14997592681752525]
# [0.82 0.82 0.25]
# 26 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bebfd0>> expected = [0.8205761316872429, 0.8201058201058196, 0.25493500240731826]
# [0.18 0.18 0.85]
# 27 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8b20>> expected = [0.17613168724279835, 0.17636684303350947, 0.8515888300433317]
# [0.32 0.32 0.95]
# 28 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bebb50>> expected = [0.3160493827160494, 0.3162845385067605, 0.9520943668753009]
# [0.27 0.28 0.92]
# 29 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beba90>> expected = [0.2748971193415638, 0.27513227513227534, 0.9167067886374579]
# [0.48 0.48 0.26]
# 30 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beb700>> expected = [0.4773662551440329, 0.4773662551440321, 0.25529610014443904]
# [0.76 0.76 0.2 ]
# 31 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be9c00>> expected = [0.7621399176954733, 0.761904761904761, 0.19764082811747719]
# [0.39 0.39 0.64]
# 32 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be9000>> expected = [0.3925925925925926, 0.39212228101116864, 0.6378189696677901]
# [0.71 0.71 0.18]
# 33 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beb460>> expected = [0.7094650205761317, 0.7089947089947088, 0.1831969186326432]
# [0.37 0.37 0.8 ]
# 34 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bea200>> expected = [0.3662551440329218, 0.36625514403292136, 0.8039239287433798]
# [0.67 0.67 0.04]
# 35 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be99c0>> expected = [0.671604938271605, 0.6713697824808929, 0.03887818969667789]
# [0.81 0.81 0.25]
# 36 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beb040>> expected = [0.805761316872428, 0.8059964726631392, 0.2543331728454502]
# [0.04 0.04 0.79]
# 37 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be9210>> expected = [0.04197530864197531, 0.04174015285126309, 0.7882763601348098]
# [0.25 0.25 0.91]
# 38 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beae30>> expected = [0.24691358024691357, 0.2469135802469129, 0.9074386133846893]
# [0.43 0.43 0.25]
# 39 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be93c0>> expected = [0.431275720164609, 0.4315108759553201, 0.24602792489167058]
# [0.47 0.47 0.27]
# 40 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bea770>> expected = [0.46748971193415634, 0.4679600235155785, 0.269740009629273]
# [0.5 0.5 0.4]
# 41 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be80a0>> expected = [0.5020576131687243, 0.5020576131687235, 0.40190178141550315]
# [0.22 0.22 0.78]
# 42 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bebf40>> expected = [0.2213991769547325, 0.22163433274544353, 0.7776841598459315]
# [0.57 0.57 0.14]
# 43 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8b80>> expected = [0.5670781893004115, 0.5673133450911223, 0.1397448242657679]
# [0.09 0.09 0.79]
# 44 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beb880>> expected = [0.08641975308641976, 0.08641975308641925, 0.7894800192585459]
# [0.24 0.24 0.87]
# 45 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be9390>> expected = [0.23621399176954733, 0.23574368018812386, 0.8719306692344727]
# [0.06 0.06 0.74]
# 46 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beaa70>> expected = [0.06008230452674897, 0.060552616108171975, 0.7367597496389021]
# [0.2  0.2  0.84]
# 47 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8910>> expected = [0.19753086419753085, 0.19753086419752997, 0.8357005296100143]
# [0.58 0.58 0.2 ]
# 48 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8310>> expected = [0.5761316872427984, 0.576131687242798, 0.1996870486278286]
# [0.77 0.77 0.15]
# 49 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bead40>> expected = [0.7679012345679013, 0.7683715461493232, 0.1505777563793933]
# [0.17 0.17 0.89]
# 50 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8f70>> expected = [0.16790123456790124, 0.16813639035861172, 0.8860134809821859]
# [0.07 0.07 0.82]
# 51 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be9b10>> expected = [0.07325102880658436, 0.07348618459729472, 0.8153586904188733]
# [0.97 0.97 0.22]
# 52 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beae90>> expected = [0.9720164609053499, 0.9717813051146376, 0.22291766971593652]
# [0.25 0.25 0.91]
# 53 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beb8b0>> expected = [0.25267489711934155, 0.2522045855379176, 0.9061145883485796]
# [0.96 0.96 0.21]
# 54 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8610>> expected = [0.9637860082304527, 0.9635508524397416, 0.2087144920558498]
# [0.24 0.24 0.9 ]
# 55 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8940>> expected = [0.24444444444444444, 0.2439741328630216, 0.9026239768897447]
# [0.18 0.18 0.83]
# 56 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beb400>> expected = [0.17777777777777776, 0.17754262198706527, 0.8275156475686086]
# [0.07 0.07 0.79]
# 57 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bea8f0>> expected = [0.06913580246913581, 0.06937095825984585, 0.7905633124699084]
# [0.3  0.3  0.91]
# 58 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be9cc0>> expected = [0.302880658436214, 0.303350970017636, 0.90912373615792]
# [0.93 0.93 0.23]
# 59 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be9750>> expected = [0.9325102880658437, 0.9329805996472658, 0.22773230621088103]
# [0.83 0.83 0.19]
# 60 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bea6e0>> expected = [0.8288065843621399, 0.8283362727807173, 0.19077997111218103]
# [0.53 0.53 0.39]
# 61 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beb490>> expected = [0.5267489711934157, 0.526748971193415, 0.38938372652864706]
# [0.56 0.56 0.21]
# 62 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bea680>> expected = [0.5555555555555556, 0.5555555555555554, 0.21172363986519016]
# [0.31 0.31 0.93]
# 63 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8460>> expected = [0.30781893004115224, 0.3080540858318628, 0.9325950890707749]
# [0.37 0.37 0.8 ]
# 64 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bea9e0>> expected = [0.37037037037037035, 0.37037037037037024, 0.7951372171401058]
# [0.48 0.48 0.24]
# 65 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beaef0>> expected = [0.4757201646090535, 0.4761904761904763, 0.2390467019740009]
# [0.46 0.46 0.27]
# 66 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bea2f0>> expected = [0.4625514403292181, 0.46208112874779417, 0.2684159845931633]
# [0.91 0.91 0.23]
# 67 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bea110>> expected = [0.9061728395061729, 0.9059376837154609, 0.23423206547905628]
# [0.35 0.35 0.8 ]
# 68 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be9270>> expected = [0.34897119341563787, 0.34920634920634797, 0.8041646605681269]
# [0.71 0.7  0.15]
# 69 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be9ae0>> expected = [0.7053497942386832, 0.70487948265726, 0.15479056331246988]
# [0.1  0.1  0.85]
# 70 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8100>> expected = [0.0962962962962963, 0.0958259847148728, 0.8460519980741453]
# [0.69 0.69 0.13]
# 71 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be90c0>> expected = [0.6921810699588478, 0.6919459141681354, 0.12758786711603276]
# [0.53 0.53 0.35]
# 72 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beb2b0>> expected = [0.5349794238683128, 0.5349794238683128, 0.3538757823784304]
# [0.32 0.32 0.95]
# 73 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be9db0>> expected = [0.3201646090534979, 0.3203997648442094, 0.9451131439576311]
# [0.59 0.59 0.23]
# 74 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bebc10>> expected = [0.5909465020576132, 0.5914168136390359, 0.22556571978815598]
# [0.72 0.72 0.23]
# 75 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be9300>> expected = [0.7209876543209877, 0.7207524985302758, 0.2298988926336062]
# [0.33 0.33 0.92]
# 76 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beace0>> expected = [0.3259259259259259, 0.3256907701352141, 0.9156234954260952]
# [0.37 0.37 0.78]
# 77 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bea050>> expected = [0.3679012345679012, 0.36743092298647717, 0.7810544053923928]
# [0.98 0.98 0.24]
# 78 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bebd30>> expected = [0.9786008230452675, 0.9788359788359777, 0.24350024073182475]
# [0.6  0.6  0.22]
# 79 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beb5b0>> expected = [0.6049382716049383, 0.6049382716049383, 0.2213529128550794]
# [0.09 0.09 0.81]
# 80 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beab30>> expected = [0.09135802469135802, 0.09112286890064603, 0.8084978334135772]
# [0.09 0.09 0.82]
# 81 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bea7a0>> expected = [0.09300411522633745, 0.09347442680775941, 0.8218584496870484]
# [0.4  0.4  0.62]
# 82 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beaf50>> expected = [0.39670781893004115, 0.3962375073486175, 0.6159123736157919]
# [0.92 0.92 0.3 ]
# 83 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be9bd0>> expected = [0.9209876543209877, 0.9212228101116988, 0.2999518536350505]
# [0.32 0.32 0.93]
# 84 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bea8c0>> expected = [0.32098765432098764, 0.3209876543209873, 0.934520943668753]
# [0.18 0.18 0.79]
# 85 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8af0>> expected = [0.18436213991769546, 0.18459729570840544, 0.7893596533461723]
# [0.54 0.54 0.3 ]
# 86 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be84f0>> expected = [0.5382716049382716, 0.538506760728982, 0.2983870967741935]
# [0.41 0.41 0.46]
# 87 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8250>> expected = [0.4090534979423868, 0.40858318636096413, 0.4622051035146846]
# [0.78 0.78 0.25]
# 88 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beaec0>> expected = [0.7794238683127572, 0.7789535567313344, 0.2520462205103514]
# [0.84 0.84 0.29]
# 89 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8070>> expected = [0.8419753086419753, 0.8424456202233976, 0.29104477611940294]
# [0.83 0.83 0.21]
# 90 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beabc0>> expected = [0.8255144032921811, 0.8259847148736039, 0.2087144920558498]
# [0.81 0.81 0.27]
# 91 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bea5f0>> expected = [0.8065843621399177, 0.8065843621399171, 0.2673326913818007]
# [0.04 0.04 0.77]
# 92 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be9f00>> expected = [0.03786008230452675, 0.037624926513814216, 0.7702214732787674]
# [0.15 0.15 0.96]
# 93 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8700>> expected = [0.14814814814814814, 0.14814814814814703, 0.964251324025036]
# [0.57 0.57 0.18]
# 94 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be9de0>> expected = [0.568724279835391, 0.5684891240446799, 0.1797063071738083]
# [0.14 0.14 0.94]
# 95 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bea230>> expected = [0.1382716049382716, 0.13874191651969348, 0.942946557534906]
# [0.41 0.41 0.5 ]
# 96 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bea860>> expected = [0.40987654320987654, 0.41034685479129784, 0.4987963408762639]
# [0.65 0.65 0.04]
# 97 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8040>> expected = [0.6510288065843621, 0.6507936507936503, 0.04429465575349062]
# [0.28 0.28 0.89]
# 98 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8430>> expected = [0.27983539094650206, 0.2798353909465021, 0.8898651901781415]
# [0.13 0.13 0.96]
# 99 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8cd0>> expected = [0.1325102880658436, 0.1322751322751312, 0.9616032739528165]
# [0.8  0.79 0.2 ]
# 100 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bebac0>> expected = [0.7950617283950617, 0.7948265726043502, 0.19631680308136734]
# [0.27 0.27 0.92]
# 101 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beb7c0>> expected = [0.27325102880658436, 0.27278071722516195, 0.9164660568127106]
# [0.04 0.04 0.8 ]
# 102 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be9870>> expected = [0.043621399176954734, 0.04409171075837648, 0.7964612421762155]
# [0.99 0.99 0.24]
# 103 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a36d70>> expected = [0.994238683127572, 0.9947089947089935, 0.2389263360616274]
# [0.95 0.95 0.21]
# 104 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b198d0>> expected = [0.9547325102880658, 0.9547325102880659, 0.20763119884448722]
# [0.19 0.19 0.8 ]
# 105 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bea1a0>> expected = [0.1860082304526749, 0.18577307466196302, 0.7970630717380837]
# [0.89 0.89 0.31]
# 106 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7bea650>> expected = [0.8864197530864197, 0.8859494415049962, 0.311386615310544]
# [0.17 0.17 0.9 ]
# 107 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b184f0>> expected = [0.16872427983539093, 0.16872427983538962, 0.9003370245546461]
# [0.31 0.31 0.93]
# 108 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b196f0>> expected = [0.30864197530864196, 0.3086419753086407, 0.9328358208955224]
# [0.72 0.72 0.19]
# 109 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1a2c0>> expected = [0.7185185185185186, 0.7189888300999403, 0.19150216658642272]
# [0.86 0.86 0.28]
# 110 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b18730>> expected = [0.8633744855967078, 0.8636096413874181, 0.2802118440057776]
# [0.13 0.13 0.96]
# 111 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b18df0>> expected = [0.13415637860082302, 0.1346266901822446, 0.9581126624939816]
# [0.99 0.99 0.25]
# 112 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1b100>> expected = [0.9934156378600824, 0.9929453262786598, 0.25337024554646126]
# [0.5  0.5  0.37]
# 113 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b183d0>> expected = [0.49794238683127573, 0.4979423868312747, 0.37325469427058255]
# [0.94 0.94 0.27]
# 114 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1a8f0>> expected = [0.9440329218106996, 0.9435626102292769, 0.2652864708714492]
# [0.46 0.46 0.25]
# 115 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1bf70>> expected = [0.460082304526749, 0.46031746031746046, 0.2520462205103514]
# [0.11 0.11 0.91]
# 116 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1b520>> expected = [0.1094650205761317, 0.10993533215755313, 0.9086422725084254]
# [0.05 0.05 0.78]
# 117 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1bcd0>> expected = [0.046090534979423864, 0.045855379188711964, 0.7814155031295135]
# [ 0.65  0.65 -0.01]
# 118 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b196c0>> expected = [0.654320987654321, 0.6543209876543212, -0.01035146846413093]
# [0.45 0.45 0.29]
# 119 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b197e0>> expected = [0.4502057613168724, 0.4497354497354493, 0.29032258064516125]
# [0.12 0.12 0.94]
# 120 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1b8e0>> expected = [0.11934156378600823, 0.11934156378600846, 0.9372893596533459]
# [0.05 0.05 0.81]
# 121 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1b160>> expected = [0.04773662551440329, 0.04820693709582535, 0.8065719788155993]
# [0.94 0.94 0.25]
# 122 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b181c0>> expected = [0.9374485596707819, 0.9376837154614925, 0.2539720751083293]
# [0.51 0.51 0.4 ]
# 123 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b19bd0>> expected = [0.5053497942386832, 0.5055849500293945, 0.3993740972556572]
# [0.56 0.56 0.19]
# 124 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b19cc0>> expected = [0.5596707818930041, 0.5596707818930042, 0.1887337506018295]
# [0.74 0.74 0.26]
# 125 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1b070>> expected = [0.7448559670781894, 0.7448559670781894, 0.2602311025517573]
# [0.93 0.93 0.26]
# 126 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1ac80>> expected = [0.9283950617283951, 0.9288653733098169, 0.256259027443428]
# [0.52 0.52 0.41]
# 127 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1bee0>> expected = [0.5226337448559671, 0.5226337448559661, 0.40707751564756856]
# [0.72 0.72 0.19]
# 128 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1ab90>> expected = [0.7152263374485597, 0.7154614932392711, 0.19390948483389503]
# [0.76 0.76 0.22]
# 129 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1b730>> expected = [0.7588477366255144, 0.7583774250440918, 0.2213529128550794]
# [0.72 0.72 0.22]
# 130 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1bb20>> expected = [0.7218106995884774, 0.7213403880070537, 0.2248435243139143]
# [0.82 0.82 0.28]
# 131 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1a1d0>> expected = [0.8164609053497943, 0.8159905937683707, 0.27768415984593164]
# [0.77 0.77 0.17]
# 132 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b19840>> expected = [0.7711934156378601, 0.7707231040564366, 0.17200288878189696]
# [0.49 0.49 0.28]
# 133 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1b790>> expected = [0.4864197530864197, 0.48618459729570773, 0.2798507462686567]
# [0.8  0.8  0.19]
# 134 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1aad0>> expected = [0.7958847736625515, 0.7954144620811281, 0.18656716417910446]
# [0.61 0.61 0.22]
# 135 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1bdc0>> expected = [0.6074074074074074, 0.6078777189888296, 0.2236398651901781]
# [0.63 0.63 0.12]
# 136 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1add0>> expected = [0.62880658436214, 0.6290417401528501, 0.11940298507462688]
# [0.25 0.25 0.94]
# 137 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1a2f0>> expected = [0.24938271604938272, 0.2498530276308042, 0.9364467982667307]
# [0.87 0.88 0.3 ]
# 138 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b185b0>> expected = [0.8748971193415638, 0.8753674309229851, 0.30199807414540203]
# [0.31 0.31 0.95]
# 139 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b19660>> expected = [0.3127572016460905, 0.31275720164608956, 0.9520943668753009]
# [0.76 0.76 0.21]
# 140 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1b340>> expected = [0.7555555555555555, 0.7560258671369784, 0.20690900337024554]
# [0.08 0.08 0.82]
# 141 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b19870>> expected = [0.08148148148148149, 0.08171663727219247, 0.818608570052961]
# [0.67 0.67 0.02]
# 142 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1b310>> expected = [0.6699588477366255, 0.670194003527337, 0.018175252768416028]
# [0.03 0.03 0.82]
# 143 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1b3a0>> expected = [0.02633744855967078, 0.025867136978247274, 0.8234232065479056]
# [ 0.67  0.67 -0.02]
# 144 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1acb0>> expected = [0.6674897119341564, 0.667254556143444, -0.01624939817043808]
# [0.7  0.7  0.11]
# 145 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b19690>> expected = [0.6962962962962963, 0.6960611405055843, 0.11314395763119883]
# [0.25 0.25 0.88]
# 146 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1b4f0>> expected = [0.254320987654321, 0.25455614344503097, 0.8756620125180549]
# [0.34 0.35 0.84]
# 147 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b18c40>> expected = [0.3448559670781893, 0.34509112286890087, 0.8403948001925853]
# [0.26 0.26 0.85]
# 148 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1a170>> expected = [0.2551440329218107, 0.25514403292181065, 0.8515888300433317]
# [0.5  0.5  0.38]
# 149 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1ab00>> expected = [0.5037037037037038, 0.5032333921222811, 0.3836061627347135]
# [0.63 0.63 0.16]
# 150 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1be20>> expected = [0.6263374485596708, 0.6261022927689588, 0.16297544535387576]
# [0.23 0.23 0.84]
# 151 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1a620>> expected = [0.2345679012345679, 0.23456790123456805, 0.8408762638420798]
# [0.07 0.07 0.83]
# 152 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1a3e0>> expected = [0.07489711934156379, 0.0746619635508523, 0.8251083293211362]
# [0.5  0.5  0.34]
# 153 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b18130>> expected = [0.49547325102880657, 0.4950029394473834, 0.3423206547905633]
# [0.7  0.7  0.17]
# 154 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b19750>> expected = [0.7045267489711935, 0.7042915931804821, 0.1674289841116996]
# [0.67 0.67 0.02]
# 155 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1b910>> expected = [0.6724279835390947, 0.6719576719576708, 0.02467501203659128]
# [0.81 0.81 0.27]
# 156 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1ab60>> expected = [0.8139917695473251, 0.8142269253380352, 0.2739528165623495]
# [0.86 0.86 0.32]
# 157 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b18820>> expected = [0.8559670781893004, 0.8559670781893001, 0.31860857005296095]
# [0.53 0.53 0.39]
# 158 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1ac20>> expected = [0.5283950617283951, 0.5279247501469726, 0.38613384689455943]
# [0.94 0.94 0.28]
# 159 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1aef0>> expected = [0.9415637860082304, 0.9417989417989414, 0.283822821376986]
# [0.51 0.51 0.38]
# 160 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b18160>> expected = [0.5102880658436214, 0.5102880658436213, 0.3781896966779008]
# [0.79 0.79 0.19]
# 161 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1a7a0>> expected = [0.7942386831275721, 0.7942386831275723, 0.19354838709677413]
# [0.14 0.14 0.98]
# 162 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b19c30>> expected = [0.14320987654320988, 0.14344503233392025, 0.9765286470871449]
# [0.83 0.83 0.21]
# 163 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b182e0>> expected = [0.8263374485596708, 0.8265726043503818, 0.20967741935483875]
# [0.53 0.53 0.39]
# 164 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b182b0>> expected = [0.5292181069958848, 0.5296884185773063, 0.3908281174771304]
# [0.01 0.01 0.8 ]
# 165 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b18700>> expected = [0.008230452674897118, 0.008230452674895972, 0.8033220991815117]
# [0.71 0.71 0.18]
# 166 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b19570>> expected = [0.7078189300411523, 0.7078189300411513, 0.18271545498314878]
# [0.76 0.76 0.21]
# 167 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1be80>> expected = [0.757201646090535, 0.7572016460905342, 0.20859412614347617]
# [0.14 0.14 0.97]
# 168 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b19720>> expected = [0.1448559670781893, 0.14462081128747784, 0.9744824265767934]
# [0.05 0.05 0.84]
# 169 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b18430>> expected = [0.050205761316872426, 0.04997060552616084, 0.8389504092441019]
# [0.95 0.95 0.24]
# 170 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1b490>> expected = [0.9481481481481482, 0.9476778365667258, 0.24241694752046217]
# [0.64 0.64 0.11]
# 171 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b191e0>> expected = [0.6444444444444445, 0.6449147560258659, 0.11157920077034189]
# [0.37 0.37 0.77]
# 172 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b18880>> expected = [0.3736625514403292, 0.37389770723103943, 0.7658883004333171]
# [0.61 0.61 0.23]
# 173 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b19c60>> expected = [0.6090534979423868, 0.6090534979423854, 0.2260471834376504]
# [0.57 0.57 0.23]
# 174 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b18100>> expected = [0.5728395061728395, 0.572604350382127, 0.23122291766971592]
# [0.54 0.54 0.3 ]
# 175 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1ae90>> expected = [0.5407407407407407, 0.5402704291593174, 0.30332209918151176]
# [0.38 0.38 0.75]
# 176 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b18e50>> expected = [0.37613168724279833, 0.3756613756613749, 0.7489167067886374]
# [0.87 0.87 0.3 ]
# 177 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b18b20>> expected = [0.8724279835390947, 0.8724279835390938, 0.2961001444390948]
# [0.65 0.65 0.1 ]
# 178 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b18b50>> expected = [0.6452674897119342, 0.6455026455026456, 0.10146846413095811]
# [0.47 0.47 0.19]
# 179 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1b9d0>> expected = [0.47242798353909465, 0.4726631393298053, 0.19077997111218103]
# [0.88 0.88 0.32]
# 180 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b18970>> expected = [0.8823045267489712, 0.8818342151675473, 0.31656234954260953]
# [0.6  0.6  0.23]
# 181 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1ad70>> expected = [0.5967078189300412, 0.5967078189300405, 0.22977852672123256]
# [0.2  0.2  0.83]
# 182 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1a7d0>> expected = [0.20329218106995883, 0.20282186948853642, 0.8272749157438611]
# [0.33 0.33 0.93]
# 183 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b199c0>> expected = [0.3325102880658436, 0.33274544385655425, 0.9274193548387096]
# [0.78 0.78 0.23]
# 184 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1ae60>> expected = [0.7769547325102881, 0.7771898883009989, 0.22905633124699087]
# [0.63 0.63 0.09]
# 185 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1a710>> expected = [0.634567901234568, 0.6343327454438565, 0.08955223880597013]
# [0.21 0.21 0.84]
# 186 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b198a0>> expected = [0.20576131687242796, 0.2057613168724277, 0.8431632161771786]
# [0.85 0.85 0.29]
# 187 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1a6b0>> expected = [0.8493827160493828, 0.8489124044679599, 0.2935724602792489]
# [0.9  0.9  0.25]
# 188 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b18190>> expected = [0.902880658436214, 0.9024103468547899, 0.2503610977371209]
# [0.44 0.44 0.23]
# 189 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b18ac0>> expected = [0.437037037037037, 0.4368018812463248, 0.22664901299951845]
# [0.69 0.69 0.15]
# 190 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1b1c0>> expected = [0.6880658436213992, 0.6878306878306866, 0.15202214732787678]
# [0.52 0.52 0.39]
# 191 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b19a80>> expected = [0.5160493827160494, 0.515579071134626, 0.39371689937409726]
# [0.73 0.73 0.26]
# 192 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b186d0>> expected = [0.731687242798354, 0.7319223985890648, 0.2595089070775156]
# [0.99 0.99 0.24]
# 193 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b18d00>> expected = [0.9901234567901235, 0.9905937683715464, 0.2413336543090997]
# [0.23 0.23 0.84]
# 194 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1ac50>> expected = [0.23374485596707817, 0.23398001175778838, 0.8389504092441019]
# [0.59 0.59 0.22]
# 195 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b18ee0>> expected = [0.5901234567901235, 0.5896531452087004, 0.21665864227250842]
# [0.57 0.57 0.13]
# 196 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1a4a0>> expected = [0.5662551440329219, 0.5667254556143444, 0.12855079441502165]
# [0.07 0.07 0.8 ]
# 197 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b192d0>> expected = [0.07078189300411523, 0.07054673721340343, 0.7963408762638421]
# [0.78 0.78 0.24]
# 198 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b19060>> expected = [0.7835390946502058, 0.7830687830687832, 0.24193548387096775]
# [0.51 0.51 0.36]
# 199 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b1a6e0>> expected = [0.5094650205761317, 0.5097001763668416, 0.3582089552238805]
# [1.   1.   0.24]
# 200 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b199f0>> expected = [0.9950617283950618, 0.9952968841857732, 0.24205584978334138]
# [0.93 0.93 0.26]
# 201 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b18e20>> expected = [0.9251028806584363, 0.9253380364491477, 0.260953298025999]
# [0.73 0.73 0.26]
# 202 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b19450>> expected = [0.7300411522633745, 0.7295708406819514, 0.2626384207992296]
# [0.79 0.79 0.19]
# 203 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7b197b0>> expected = [0.7868312757201646, 0.7865961199294524, 0.18813192103996146]
# [0.86 0.86 0.3 ]
# 204 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a876b3d0>> expected = [0.8592592592592593, 0.8594944150499693, 0.2987481945113144]
# [0.45 0.45 0.28]
# 205 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96ad3ab190>> expected = [0.4493827160493827, 0.4491475602586714, 0.27611940298507454]
# [0.68 0.68 0.1 ]
# 206 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b974fd9a560>> expected = [0.6806584362139918, 0.6801881246325685, 0.10074626865671638]
# [0.6 0.6 0.2]
# 207 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7beb4c0>> expected = [0.6024691358024692, 0.6019988242210452, 0.19703899855560902]
# [0.37 0.37 0.77]
# 208 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b974fd9a680>> expected = [0.3687242798353909, 0.36919459141681266, 0.769378911892152]
# [0.85 0.85 0.3 ]
# 209 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96ad3ab1f0>> expected = [0.8510288065843622, 0.8512639623750733, 0.2970630717380838]
# [0.41 0.41 0.56]
# 210 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96ad3a84f0>> expected = [0.40658436213991767, 0.40681951793062865, 0.5597014925373135]
# [0.07 0.07 0.74]
# 211 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a8769330>> expected = [0.06502057613168725, 0.06525573192239875, 0.7422965816080885]
# [0.6  0.6  0.21]
# 212 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a876ae30>> expected = [0.6016460905349794, 0.6014109347442673, 0.20895522388059695]
# [0.12 0.12 0.95]
# 213 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96ac09b0a0>> expected = [0.11769547325102882, 0.11816578483245088, 0.95173326913818]
# [0.25 0.25 0.89]
# 214 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96ad3ab280>> expected = [0.2510288065843621, 0.2510288065843618, 0.8932354357246027]
# [0.55 0.55 0.21]
# 215 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96ad3aaec0>> expected = [0.5539094650205761, 0.5543797766019978, 0.21316803081367353]
# [0.75 0.75 0.26]
# ...
# [0.83 0.83 0.22]
# 318 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a68400>> expected = [0.831275720164609, 0.8312757201646086, 0.21689937409725568]
# [0.02 0.02 0.84]
# 319 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a6a0b0>> expected = [0.023045267489711932, 0.023515579071133885, 0.8361819932595088]
# [0.97 0.97 0.21]
# 320 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a6a920>> expected = [0.9670781893004116, 0.9670781893004108, 0.2114829080404429]
# [0.5  0.5  0.38]
# 321 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a68c10>> expected = [0.502880658436214, 0.5026455026455015, 0.3785507944150217]
# [0.29 0.29 0.87]
# 322 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a69480>> expected = [0.28641975308641976, 0.2868900646678423, 0.8690418873375058]
# [0.64 0.64 0.11]
# 323 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a69de0>> expected = [0.6378600823045267, 0.6378600823045257, 0.11097737120847373]
# [0.59 0.59 0.22]
# 324 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a692a0>> expected = [0.5860082304526749, 0.5855379188712515, 0.21677900818488205]
# [0.36 0.36 0.78]
# 325 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a69ed0>> expected = [0.36131687242798355, 0.3615520282186946, 0.7846653827636013]
# [0.6  0.6  0.21]
# 326 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a68be0>> expected = [0.6008230452674898, 0.6008230452674894, 0.21280693307655274]
# [0.6  0.6  0.23]
# 327 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a69930>> expected = [0.5958847736625514, 0.5961199294532626, 0.23062108810784787]
# [0.91 0.91 0.26]
# 328 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a69e10>> expected = [0.9094650205761318, 0.9094650205761319, 0.26396244583533945]
# [0.75 0.75 0.21]
# 329 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a6b460>> expected = [0.7547325102880659, 0.7542621987066429, 0.2146124217621569]
# [0.22 0.22 0.77]
# 330 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a682e0>> expected = [0.21810699588477364, 0.21810699588477256, 0.7746750120365912]
# [0.25 0.25 0.91]
# 331 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a69cf0>> expected = [0.248559670781893, 0.24808935920047048, 0.9068367838228212]
# [0.02 0.02 0.82]
# 332 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a6a020>> expected = [0.02139917695473251, 0.021164021164020497, 0.8220991815117958]
# [0.31 0.31 0.96]
# 333 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a68130>> expected = [0.3094650205761317, 0.30922986478542036, 0.9588348579682234]
# [0.04 0.04 0.78]
# 334 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a6b310>> expected = [0.040329218106995884, 0.040564373897707284, 0.7811747713047664]
# [0.27 0.27 0.9 ]
# 335 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a69780>> expected = [0.2707818930041152, 0.27101704879482647, 0.903105440539239]
# [0.09 0.09 0.8 ]
# 336 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a6beb0>> expected = [0.09053497942386832, 0.09053497942386812, 0.7958594126143476]
# [0.05 0.05 0.79]
# 337 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a69e40>> expected = [0.046913580246913576, 0.04644326866548987, 0.7928502648050072]
# [0.42 0.42 0.33]
# 338 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b974ff13730>> expected = [0.4222222222222222, 0.42269253380364447, 0.33353394318728935]
# [0.18 0.18 0.79]
# 339 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a8615390>> expected = [0.18024691358024691, 0.18048206937095834, 0.7927298988926336]
# [0.1  0.1  0.81]
# 340 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a8615b70>> expected = [0.10205761316872429, 0.10229276895943507, 0.8149975926817524]
# [0.46 0.46 0.24]
# 341 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a8616650>> expected = [0.46172839506172836, 0.46149323927101626, 0.24205584978334138]
# [0.59 0.59 0.21]
# 342 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a8616230>> expected = [0.5876543209876544, 0.5878894767783649, 0.2130476649013]
# [0.42 0.42 0.34]
# 343 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a8614c70>> expected = [0.41893004115226334, 0.4191651969429735, 0.34220028887818965]
# [0.06 0.06 0.71]
# 344 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a8615900>> expected = [0.0617283950617284, 0.06172839506172778, 0.7114829080404429]
# [0.5  0.5  0.34]
# 345 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a8616560>> expected = [0.4962962962962963, 0.49676660787771887, 0.3372652864708715]
# [0.61 0.61 0.2 ]
# 346 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a86154b0>> expected = [0.6106995884773663, 0.610229276895943, 0.20197400096292728]
# [0.39 0.39 0.64]
# 347 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a86156f0>> expected = [0.3917695473251029, 0.39153439153439074, 0.6441983630235917]
# [0.44 0.44 0.25]
# 348 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96ab8455a0>> expected = [0.4378600823045267, 0.4373897707231027, 0.25216658642272505]
# [0.73 0.73 0.25]
# 349 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a8615780>> expected = [0.7267489711934156, 0.727219282774838, 0.2477130476649012]
# [0.64 0.64 0.11]
# 350 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a8614310>> expected = [0.6419753086419754, 0.6419753086419746, 0.10893115069812231]
# [0.59 0.59 0.21]
# 351 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7be8190>> expected = [0.5893004115226338, 0.5890652557319225, 0.2071497351949928]
# [0.89 0.89 0.31]
# 352 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a86153f0>> expected = [0.8946502057613169, 0.894179894179894, 0.31042368801155507]
# [0.34 0.34 0.85]
# 353 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a86165f0>> expected = [0.3390946502057613, 0.3386243386243386, 0.8464130958112662]
# [0.39 0.39 0.65]
# 354 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96ab8455d0>> expected = [0.3893004115226337, 0.38977072310405525, 0.646605681271064]
# [0.84 0.84 0.28]
# 355 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a8616800>> expected = [0.8403292181069959, 0.8400940623162843, 0.2833413577274916]
# [0.75 0.75 0.21]
# 356 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a68ca0>> expected = [0.7539094650205762, 0.753674309229865, 0.21280693307655274]
# [0.27 0.27 0.89]
# 357 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96ab845630>> expected = [0.26913580246913577, 0.2686654908877131, 0.8861338468945593]
# [0.51 0.51 0.38]
# 358 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a68b50>> expected = [0.508641975308642, 0.5091122868900637, 0.38396726047183427]
# [0.68 0.68 0.05]
# 359 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a8614be0>> expected = [0.6765432098765433, 0.6760728982951196, 0.049470389985556085]
# [0.54 0.54 0.35]
# 360 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a68f40>> expected = [0.5358024691358025, 0.5355673133450907, 0.3537554164660568]
# [0.6  0.6  0.22]
# 361 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a55210>> expected = [0.5991769547325103, 0.5996472663139318, 0.22111218103033214]
# [0.37 0.37 0.81]
# 362 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a69c60>> expected = [0.3654320987654321, 0.36566725455614346, 0.8109051516610494]
# [0.46 0.46 0.27]
# 363 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a69060>> expected = [0.45925925925925926, 0.4597295708406808, 0.26504573904670203]
# [0.05 0.05 0.84]
# 364 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a56950>> expected = [0.05185185185185185, 0.05232216343327423, 0.8372652864708713]
# [0.59 0.59 0.25]
# 365 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a8615990>> expected = [0.5917695473251029, 0.5920047031158138, 0.2526480500722196]
# [0.08 0.08 0.8 ]
# 366 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a69300>> expected = [0.07818930041152264, 0.0781893004115215, 0.7993500240731825]
# [0.7  0.7  0.12]
# 367 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a57430>> expected = [0.6995884773662552, 0.6995884773662553, 0.12277323062108814]
# [0.81 0.81 0.28]
# 368 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a69240>> expected = [0.811522633744856, 0.8112874779541439, 0.275999037072701]
# [0.3  0.3  0.93]
# 369 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a8615810>> expected = [0.29958847736625516, 0.2998236331569668, 0.9297063071738082]
# [0.76 0.76 0.21]
# 370 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a8616350>> expected = [0.7613168724279836, 0.7613168724279831, 0.20967741935483875]
# [0.24 0.24 0.88]
# 371 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a8616680>> expected = [0.23868312757201646, 0.23868312757201515, 0.8767453057294173]
# [0.34 0.34 0.94]
# 372 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a6aa70>> expected = [0.3358024691358025, 0.3362727807172252, 0.9405392392874338]
# [0.31 0.31 0.91]
# 373 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a572e0>> expected = [0.3061728395061728, 0.3057025279247494, 0.9121328839672603]
# [0.45 0.45 0.25]
# 374 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a8616830>> expected = [0.44855967078189296, 0.44855967078189174, 0.25168512277323063]
# [0.44 0.44 0.21]
# 375 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a553c0>> expected = [0.442798353909465, 0.44326866549088706, 0.20775156475686085]
# [0.38 0.38 0.7 ]
# 376 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a566b0>> expected = [0.3802469135802469, 0.3797766019988238, 0.7020943668753009]
# [0.88 0.88 0.31]
# 377 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a576a0>> expected = [0.877366255144033, 0.8771310993533206, 0.31307173808377464]
# [0.15 0.16 0.92]
# 378 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a552a0>> expected = [0.15473251028806584, 0.1552028218694872, 0.9157438613384689]
# [0.66 0.66 0.02]
# 379 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a55330>> expected = [0.6576131687242799, 0.6578483245149904, 0.024073182474723176]
# [0.36 0.36 0.77]
# 380 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a55ff0>> expected = [0.3621399176954732, 0.3621399176954725, 0.7723880597014924]
# [0.09 0.09 0.82]
# 381 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a55570>> expected = [0.09382716049382717, 0.09406231628453732, 0.8180067404910928]
# [0.32 0.32 0.95]
# 382 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a57520>> expected = [0.31522633744855966, 0.3156966490299826, 0.9543813192103995]
# [0.2  0.2  0.84]
# 383 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a55f00>> expected = [0.2024691358024691, 0.20223398001175674, 0.838589311506981]
# [0.58 0.58 0.23]
# 384 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a56e90>> expected = [0.5810699588477367, 0.5808348030570247, 0.23338950409244097]
# [0.95 0.95 0.22]
# 385 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a57880>> expected = [0.9530864197530865, 0.9535567313345084, 0.22339913336543094]
# [0.66 0.66 0.06]
# 386 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a57250>> expected = [0.6584362139917695, 0.6584362139917683, 0.05753490611458839]
# [0.71 0.71 0.16]
# 387 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a57970>> expected = [0.7069958847736626, 0.7072310405643734, 0.1605681271064035]
# [0.53 0.53 0.4 ]
# 388 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7b96a7a557e0>> expected = [0.5300411522633746, 0.530276308054086, 0.4033461723639864]

# %% [markdown]
# #Deep learning for time series forecasting

# %%
# read the data
X = pd.read_csv ('/content/test.csv')
y = pd.read_csv ('/content/train.csv')

# sampling the data in X
X = X ['date'].sample(5000)

# sampling the data in y
y = y ['date'].sample (5000)

# %%
# setting T - the number of lag variables
T = 1

# setting the horizon, as we interesting in predicting next day
HORIZON = 1

# %%
# convert datasets to time series
X = pd.to_datetime(X)
y = pd.to_datetime(y)

# %%
# create train set containing only the model features
X_train, y_train, X_test, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

print ('Training data shape X: ', X_train.shape)
print ('Test data shape X: ', X_test.shape)
print ('Training data shape y: ', y_train.shape)
print ('Test data shape y: ', y_test.shape)
# Out:
# Training data shape X:  (2500,)
# Test data shape X:  (2500,)
# Training data shape y:  (2500,)
# Test data shape y:  (2500,)

# %%
# create a validation set
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size=0.5)

print ('Validation data shape X: ', X_valid.shape)
print ('Validation data shape y: ', y_valid.shape)
# Out:
# Validation data shape X:  (1250,)
# Validation data shape y:  (1250,)

# %%
# converting data
X_train = np.asarray(X_train).astype(np.float32)
y_train = np.asarray(y_train).astype(np.float32)
X_test = np.asarray(X_test).astype(np.float32)
y_test = np.asarray(y_test).astype(np.float32)
X_valid = np.asarray (X_valid).astype (np.float32)
y_valid = np.asarray (y_valid).astype (np.float32)

# %%
# rescale the data to 0-1 scale
min_max_scaler = MinMaxScaler(feature_range=(0, 1))
X_train = min_max_scaler.fit_transform(X_train.reshape(-1, 1))
y_train = min_max_scaler.fit_transform(y_train.reshape(-1, 1))
X_test = min_max_scaler.fit_transform(X_test.reshape(-1, 1))
y_test = min_max_scaler.fit_transform(y_test.reshape(-1, 1))
X_valid = min_max_scaler.fit_transform(X_valid.reshape(-1, 1))
y_valid = min_max_scaler.fit_transform(y_valid.reshape(-1, 1))

# %%
# reshape the data
X_train = np.reshape(X_train, (X_train.shape[0], T, X_train.shape[1]))
y_train = np.reshape(y_train, (y_train.shape[0], T, y_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], T, X_test.shape[1]))
y_test = np.reshape(y_test, (y_test.shape[0], T, y_test.shape[1]))
X_valid = np.reshape(X_valid, (X_valid.shape[0], T, X_valid.shape[1]))
y_valid = np.reshape(y_valid, (y_valid.shape[0], T, y_valid.shape[1]))

# %%
#Univariate models

# number of units in the RNN layer
LATENT_DIM = 5

# number of samples per mini-batch
BATCH_SIZE = 32

# maximum number of times the training algorithm will cycle through all samples
EPOCHS = 15

# define model and create a Sequential model
model = Sequential ()
model.add (GRU (LATENT_DIM, input_shape = (T, 1)))
model.add (Dense (HORIZON))

model.compile (optimizer = 'RMSprop', loss = 'mse')
model.summary ()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 5)                 120
#
#  dense (Dense)               (None, 1)                 6
#
# =================================================================
# Total params: 126
# Trainable params: 126
# Non-trainable params: 0
# _________________________________________________________________

# %%
# specify early stop criteria
GRU_earlystop = EarlyStopping (monitor = 'val_loss', min_delta = 0, patience = 5)

# fit our model
history = model.fit (X_train, y_train, batch_size = BATCH_SIZE, epochs = EPOCHS, validation_data = (X_valid, y_valid),
                           callbacks = [GRU_earlystop], verbose = 1)
# Out:
# Epoch 1/15
# 40/40 [==============================] - 6s 21ms/step - loss: 0.1688 - val_loss: 0.1223
# Epoch 2/15
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1202 - val_loss: 0.1083
# Epoch 3/15
# 40/40 [==============================] - 0s 6ms/step - loss: 0.1102 - val_loss: 0.1036
# Epoch 4/15
# 40/40 [==============================] - 0s 6ms/step - loss: 0.1054 - val_loss: 0.0999
# Epoch 5/15
# 40/40 [==============================] - 0s 6ms/step - loss: 0.1022 - val_loss: 0.0976
# Epoch 6/15
# 40/40 [==============================] - 0s 7ms/step - loss: 0.1005 - val_loss: 0.0963
# Epoch 7/15
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0993 - val_loss: 0.0948
# Epoch 8/15
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0984 - val_loss: 0.0962
# Epoch 9/15
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0979 - val_loss: 0.0937
# Epoch 10/15
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0976 - val_loss: 0.0935
# Epoch 11/15
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0974 - val_loss: 0.0937
# Epoch 12/15
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0972 - val_loss: 0.0932
# Epoch 13/15
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0972 - val_loss: 0.0931
# Epoch 14/15
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0971 - val_loss: 0.0932
# Epoch 15/15
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0970 - val_loss: 0.0935

# %%
# plot the epochs and train_loss and val_loss
plot_df = pd.DataFrame.from_dict({'train_loss':history.history['loss'], 'val_loss':history.history['val_loss']})
plot_df.plot(logy=True, figsize=(10,10), fontsize=12)
plt.xlabel('epoch', fontsize=5)
plt.ylabel('loss', fontsize=5)
plt.show()

# %%
# make the predictiondson the X_test and compare those predictions on the y_test
ts_predictions = model.predict (X_test)
ev_ts_data = pd.DataFrame (ts_predictions)
ev_ts_data ['prediction' ]= pd.DataFrame (ts_predictions)
ev_ts_data ['actual'] = np.transpose (y_test).ravel ()

# evaluate our model and compute MAPE (mean absolute percentage error)
def mape (ts_predictions, actuals):
    return ((ts_predictions - actuals).abs () / actuals).mean ()

mape (ev_ts_data ['prediction'], ev_ts_data ['actual'])
# Out:
# 79/79 [==============================] - 1s 2ms/step
# inf

# %%
# plot the count of predictions
ev_ts_data ['actual' < '0.3'].plot (x = 'prediction', style = ['r', 'b'], figsize = (15, 8))
plt.xlabel ('prediction', fontsize = 12)
plt.ylabel ('count', fontsize = 12)
plt.show ()

# %%
#Let's try to apply machine learning methods to transactions datasets

transactions.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83488 entries, 0 to 83487
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         83488 non-null  int64
#  1   date          83488 non-null  float64
#  2   store_nbr     83488 non-null  int64
#  3   transactions  83488 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 2.5 MB

# %%
X = transactions ['date']
y = transactions ['transactions']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=21)
# converting data
X_train = np.asarray(X_train).astype(np.float32)
y_train = np.asarray(y_train).astype(np.float32)
X_test = np.asarray(X_test).astype(np.float32)
y_test = np.asarray(y_test).astype(np.float32)

# rescale the data to 0-1 scale
min_max_scaler = MinMaxScaler(feature_range=(0, 1))
X_train = min_max_scaler.fit_transform(X_train.reshape(-1, 1))
y_train = min_max_scaler.fit_transform(y_train.reshape(-1, 1))
X_test = min_max_scaler.fit_transform(X_test.reshape(-1, 1))
y_test = min_max_scaler.fit_transform(y_test.reshape(-1, 1))

# reshape the data
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1]))
y_train = np.reshape(y_train, (y_train.shape[0], y_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1]))
y_test = np.reshape(y_test, (y_test.shape[0], y_test.shape[1]))
# check the data shape
print ('Training data shape X: ', X_train.shape)
print ('Test data shape X: ', X_test.shape)
print ('Training data shape y: ', y_train.shape)
print ('Test data shape y: ', y_test.shape)
# Out:
# Training data shape X:  (41744, 1)
# Test data shape X:  (41744, 1)
# Training data shape y:  (41744, 1)
# Test data shape y:  (41744, 1)

# %%
from sklearn.linear_model import LinearRegression
lr_model = LinearRegression()
lr_model.fit(X_train, X_test)

lr_y = y_test
lr_y_fit = lr_model.predict(X_train)
lr_y_pred = lr_model.predict(X_test)

lr_residuals = lr_y_pred - lr_y
lr_rmse = np.sqrt(np.sum(np.power(lr_residuals,2)) / len(lr_residuals))
print('RMSE = %.2f' % lr_rmse)
# Out:
# RMSE = 0.33
